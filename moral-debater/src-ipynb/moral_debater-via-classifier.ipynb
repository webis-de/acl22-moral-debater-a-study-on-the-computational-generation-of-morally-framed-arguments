# %%
# %load_ext autoreload

# %%
import os
import sys
import pickle
import glob

os.environ['CUDA_VISIBLE_DEVICES'] = '4'

sys.path.insert(0, '../src-py/')
sys.path.insert(0, '../../src-py/')

# %%
# %autoreload
import json
from moral_debater import *
import pandas as pd
import bert_moral_classification

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Given a topic:
# - Collect some thousands of sentences on it.
# - classify sentences based on morals.
# - Keep the ones that reflect the correct moral.
# - Create a narrative from them

# %%
data_path = '../../../moral-debater-data/moal-narratives/'

# %%
morals = ['care', 'authority', 'fairness', 'loyalty', 'purity']

# %%
debater_api = DebaterApi('0abeffa5335cc942fc7c43e75d41fe33L05')
query_size=3000

# %%
top_20_big_issues = [
 'Gay Marriage',
 'Abortion',
 'Death Penalty',
 'Minimum Wage',
 'Affirmative Action',
 'Barack Obama',
 'Capitalism',
 'Global Warming',
 'Euthanasia',
 'Animal Rights',
 'Electoral College',
 'National Health Care',
 'Free Trade',
 'Federal Reserve',
 'Welfare',
 'Border Fence',
 'Medical Marijuana',
 'Flat Tax',
 'Legalized Prostitution',
 'Socialism'
]

# %%
moral_dict = {
    'binding': set(['loyalty', 'authority', 'purity']),
    'individual': set(['fairness', 'care'])
}

# %%
topic_narratives = collect_narratives_via_classifier(top_20_big_issues[0:2], moral_dict, 10000, old_narratives={},  use_cache=False)
# Out:
# TermWikifierClient:   0%|          | 0/2 [00:00<?, ?it/s]
# TermWikifierClient: 100%|██████████| 2/2 [00:00<00:00,  6.38it/s]
# [['Same-sex marriage'], ['Abortion']]
# TermWikifierClient: 100%|██████████| 2/2 [00:17<00:00,  8.75s/it]
# TermWikifierClient: 100%|██████████| 2/2 [03:04<00:00, 92.30s/it]
# No CUDA GPUs are available

# %%
def check_narratives(narratives):
    for topic in narratives:
        for stance in ['pro', 'con']:
            for m in ['binding', 'individual', 'general']:
                print(topic, m, stance)
                if '{}_{}_narrative'.format(m,stance) in narratives[topic]:
                    analyse_speech(narratives[topic]['{}_{}_narrative'.format(m,stance)])
                else:
                    print('{}_{}_narrative of {} is missing'.format(m,stance, topic) )

# %%
pickle.dump(topic_narratives, open(data_path + 'moral_narratives_via_classifier_for_top_20_big_issues.pkl', 'wb'))

# %%
check_narratives(topic_narratives)
# Out:
# Gay Marriage binding pro
# Number of Paragraphs: 7
# Number of arguments: 191
# Number of filtered-out arguments: 695
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Majority', 'Legalization', 'LGBT', 'Man', 'Amendment', 'Ban (law)']
# ====
# Gay Marriage individual pro
# Number of Paragraphs: 7
# Number of arguments: 123
# Number of filtered-out arguments: 297
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Child', 'LGBT rights by country or territory', 'LGBT', 'Ban (law)', 'LGBT community']
# ====
# Gay Marriage general pro
# Number of Paragraphs: 7
# Number of arguments: 327
# Number of filtered-out arguments: 1028
# Number of key points: 0
# Number of clusters: 9
# Clusters: ['Voting', 'Constitutionality', 'LGBT rights by country or territory', 'Barack Obama', 'Ban (law)', 'LGBT', 'Majority', 'Legalization', 'Gay']
# ====
# Gay Marriage binding con
# Number of Paragraphs: 7
# Number of arguments: 133
# Number of filtered-out arguments: 753
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Ban (law)', 'Zoophilia', 'Wrongdoing', '2008 California Proposition 8', 'Gay']
# ====
# Gay Marriage individual con
# Number of Paragraphs: 7
# Number of arguments: 71
# Number of filtered-out arguments: 349
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Damage', 'Society', 'Child', 'Gay']
# ====
# Gay Marriage general con
# Number of Paragraphs: 7
# Number of arguments: 222
# Number of filtered-out arguments: 1133
# Number of key points: 0
# Number of clusters: 7
# Clusters: ['Constitutional amendment', 'Wrongdoing', 'Man', 'Heterosexuality', 'Ban (law)', 'Child', 'Gay']
# ====
# Abortion binding pro
# binding_pro_narrative of Abortion is missing
# Abortion individual pro
# individual_pro_narrative of Abortion is missing
# Abortion general pro
# Number of Paragraphs: 7
# Number of arguments: 553
# Number of filtered-out arguments: 2788
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Ban (law)', 'Opinion poll', 'Life', 'Protection', 'Common good', 'Birth control', 'Decriminalization', 'Law', 'Supreme court', 'Gender']
# ====
# Abortion binding con
# binding_con_narrative of Abortion is missing
# Abortion individual con
# individual_con_narrative of Abortion is missing
# Abortion general con
# Number of Paragraphs: 7
# Number of arguments: 693
# Number of filtered-out arguments: 2648
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Sin', 'Murder', 'Risk', 'Mother', 'Crime', 'Fetus', 'Wrongdoing', 'Law', 'Imprisonment', 'Birth control']
# ====
# Death Penalty binding pro
# Number of Paragraphs: 7
# Number of arguments: 895
# Number of filtered-out arguments: 2326
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Legislation', 'Jury', 'Washington, D.C.', 'Species reintroduction', 'Treason', 'Murder', 'Law', 'Constitution', 'Advocate', 'Crime']
# ====
# Death Penalty individual pro
# Number of Paragraphs: 7
# Number of arguments: 177
# Number of filtered-out arguments: 680
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Human rights', 'Murder', 'Illegal drug trade', 'Acceptability', 'Prosecutor', 'Death']
# ====
# Death Penalty general pro
# Number of Paragraphs: 7
# Number of arguments: 1102
# Number of filtered-out arguments: 3072
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Deterrence (penology)', 'Constitution', 'Murder', 'Jury', 'Crime', 'Rape', 'Guilt (law)', 'Death', 'Ban (law)', 'United Nations moratorium on the death penalty']
# ====
# Death Penalty binding con
# Number of Paragraphs: 7
# Number of arguments: 217
# Number of filtered-out arguments: 3004
# Number of key points: 0
# Number of clusters: 7
# Clusters: ['Constitutionality', 'Matter', 'Wrongdoing', 'Stern', 'Crime', 'Life imprisonment', 'Law']
# ====
# Death Penalty individual con
# Number of Paragraphs: 7
# Number of arguments: 90
# Number of filtered-out arguments: 767
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Constitutionality', 'Cruelty', 'Judiciary', 'Regard (DJ)']
# ====
# Death Penalty general con
# Number of Paragraphs: 7
# Number of arguments: 312
# Number of filtered-out arguments: 3862
# Number of key points: 0
# Number of clusters: 8
# Clusters: ['Constitutionality', 'Bodily harm', 'Cruelty', 'Stern', 'Crime', 'Wrongdoing', 'Inhuman or degrading treatment', 'Death']
# ====
# Minimum Wage binding pro
# Number of Paragraphs: 7
# Number of arguments: 119
# Number of filtered-out arguments: 118
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Workforce', 'Mayor', 'Family', 'Economic growth', 'Legislation']
# ====
# Minimum Wage individual pro
# Number of Paragraphs: 7
# Number of arguments: 109
# Number of filtered-out arguments: 193
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Maxima and minima', 'Economic inequality', 'Employment', 'Productivity', 'Poverty']
# ====
# Minimum Wage general pro
# Number of Paragraphs: 7
# Number of arguments: 231
# Number of filtered-out arguments: 315
# Number of key points: 0
# Number of clusters: 7
# Clusters: ['Job', 'Poverty', 'Woman', 'Hour', 'Workforce', 'Employment', 'Government']
# ====
# Minimum Wage binding con
# Number of Paragraphs: 7
# Number of arguments: 41
# Number of filtered-out arguments: 196
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Poverty', 'Business', 'Constitutionality', 'Maxima and minima']
# ====
# Minimum Wage individual con
# No group 1
# Minimum Wage general con
# Number of Paragraphs: 7
# Number of arguments: 121
# Number of filtered-out arguments: 425
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Workforce', 'Unemployment', 'Constitutionality', 'Maxima and minima', 'Job']
# ====
# Affirmative Action binding pro
# Number of Paragraphs: 7
# Number of arguments: 151
# Number of filtered-out arguments: 380
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Law', 'Student', 'Policy', 'Woman', 'Understanding', 'Socialism']
# ====
# Affirmative Action individual pro
# Number of Paragraphs: 7
# Number of arguments: 127
# Number of filtered-out arguments: 232
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Employment', 'Discrimination', 'University', 'Policy', 'Utilitarianism']
# ====
# Affirmative Action general pro
# Number of Paragraphs: 7
# Number of arguments: 295
# Number of filtered-out arguments: 634
# Number of key points: 0
# Number of clusters: 8
# Clusters: ['Discrimination', 'Effectiveness', 'Supreme court', 'Woman', 'Society', 'Government', 'Minority group', 'Business']
# ====
# Affirmative Action binding con
# Number of Paragraphs: 7
# Number of arguments: 107
# Number of filtered-out arguments: 424
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Ban (law)', 'Clarence Thomas', 'University and college admission', 'Nation', 'Institution']
# ====
# Affirmative Action individual con
# Number of Paragraphs: 7
# Number of arguments: 73
# Number of filtered-out arguments: 286
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Discrimination', 'Harm', 'Government', 'Book']
# ====
# Affirmative Action general con
# Number of Paragraphs: 7
# Number of arguments: 183
# Number of filtered-out arguments: 746
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Harm', 'Racism', 'Wikipedia', 'Policy', 'Ban (law)', 'Wrongdoing']
# ====
# Barack Obama binding pro
# Number of Paragraphs: 7
# Number of arguments: 45
# Number of filtered-out arguments: 53
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['2008 United States presidential election', 'Leadership', 'Secretary of state', 'Job']
# ====
# Barack Obama individual pro
# Number of Paragraphs: 7
# Number of arguments: 26
# Number of filtered-out arguments: 49
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Peace', 'Continuation', 'Crisis', 'Policy']
# ====
# Barack Obama general pro
# Number of Paragraphs: 7
# Number of arguments: 73
# Number of filtered-out arguments: 112
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Peace', '2008 United States presidential election', 'Job', 'Evolution']
# ====
# Barack Obama binding con
# Number of Paragraphs: 2
# Number of arguments: 6
# Number of filtered-out arguments: 92
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Candidate', 'Islamic terrorism', 'Effectiveness', 'Election']
# ====
# Barack Obama individual con
# Number of Paragraphs: 6
# Number of arguments: 11
# Number of filtered-out arguments: 64
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['School', 'My Country', 'Economy', 'Reign of Terror']
# ====
# Barack Obama general con
# Number of Paragraphs: 7
# Number of arguments: 21
# Number of filtered-out arguments: 164
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Economy', 'Candidate', 'My Country', 'Policy']
# ====
# Capitalism binding pro
# Number of Paragraphs: 7
# Number of arguments: 193
# Number of filtered-out arguments: 212
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Socialism', 'Workforce', 'Manifesto', 'Man', 'Socioeconomics', 'Woman']
# ====
# Capitalism individual pro
# Number of Paragraphs: 7
# Number of arguments: 153
# Number of filtered-out arguments: 204
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['War', 'Free market', 'Book', 'Failure', 'System', 'Society']
# ====
# Capitalism general pro
# Number of Paragraphs: 7
# Number of arguments: 361
# Number of filtered-out arguments: 454
# Number of key points: 0
# Number of clusters: 9
# Clusters: ['Workforce', 'War', 'System', 'Scholar', 'Institution', 'Communism', 'Planet', 'Free market', 'Economic system']
# ====
# Capitalism binding con
# Number of Paragraphs: 7
# Number of arguments: 82
# Number of filtered-out arguments: 323
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Free market', 'Communism', 'Freedom', 'Socialism']
# ====
# Capitalism individual con
# Number of Paragraphs: 7
# Number of arguments: 76
# Number of filtered-out arguments: 281
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Freedom', 'Peace', 'Economy', 'Artist']
# ====
# Capitalism general con
# Number of Paragraphs: 7
# Number of arguments: 172
# Number of filtered-out arguments: 643
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['System', 'Free market', 'Socialism', 'Conquest', 'Prosperity', 'Poverty']
# ====
# Euthanasia binding pro
# Number of Paragraphs: 7
# Number of arguments: 70
# Number of filtered-out arguments: 222
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Law', 'Legalization', 'Assisted suicide', 'Public figure']
# ====
# Euthanasia individual pro
# Number of Paragraphs: 7
# Number of arguments: 64
# Number of filtered-out arguments: 168
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Terminal illness', 'Legislation', 'Patient', 'Acceptability']
# ====
# Euthanasia general pro
# Number of Paragraphs: 7
# Number of arguments: 135
# Number of filtered-out arguments: 414
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Assisted suicide', 'States and territories of Australia', 'Disease', 'Animal', 'Patient']
# ====
# Euthanasia binding con
# Number of Paragraphs: 7
# Number of arguments: 97
# Number of filtered-out arguments: 195
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['The Age', 'Suicide', 'Assisted suicide', 'Murder']
# ====
# Euthanasia individual con
# Number of Paragraphs: 7
# Number of arguments: 62
# Number of filtered-out arguments: 170
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Abortion', 'Murder', 'Legalization', 'Assisted suicide']
# ====
# Euthanasia general con
# Number of Paragraphs: 7
# Number of arguments: 177
# Number of filtered-out arguments: 372
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Ethics', 'Abortion', 'Assisted suicide', 'Catholic theology', 'Patient', 'Death']
# ====
# Animal Rights binding pro
# Number of Paragraphs: 7
# Number of arguments: 39
# Number of filtered-out arguments: 48
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Role', 'Agriculture', 'Inherence', 'Humanity (virtue)']
# ====
# Animal Rights individual pro
# Number of Paragraphs: 7
# Number of arguments: 258
# Number of filtered-out arguments: 283
# Number of key points: 0
# Number of clusters: 8
# Clusters: ['Advocate', 'Veganism', 'Role', 'Right to keep and bear arms', 'Law', 'Science', 'Protection', 'Government']
# ====
# Animal Rights general pro
# Number of Paragraphs: 7
# Number of arguments: 299
# Number of filtered-out arguments: 335
# Number of key points: 0
# Number of clusters: 8
# Clusters: ['Vegetarianism', 'Protection', 'Respect', 'Advocate', 'Right to keep and bear arms', 'Law', 'Science', 'Role']
# ====
# Animal Rights binding con
# Number of Paragraphs: 5
# Number of arguments: 10
# Number of filtered-out arguments: 77
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Dignity', 'Demand', 'Soil erosion', 'Natural law']
# ====
# Animal Rights individual con
# Number of Paragraphs: 7
# Number of arguments: 21
# Number of filtered-out arguments: 520
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Social exclusion', 'Injury', 'Natural environment', 'Intellectual property']
# ====
# Animal Rights general con
# Number of Paragraphs: 7
# Number of arguments: 31
# Number of filtered-out arguments: 603
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Social exclusion', 'Wrongdoing', 'Suffering', 'Demand']
# ====
# Electoral College binding pro
# Number of Paragraphs: 2
# Number of arguments: 3
# Number of filtered-out arguments: 29
# Number of key points: 0
# Number of clusters: 0
# Clusters: []
# ====
# Electoral College individual pro
# Number of Paragraphs: 2
# Number of arguments: 2
# Number of filtered-out arguments: 16
# Number of key points: 0
# Number of clusters: 0
# Clusters: []
# ====
# Electoral College general pro
# Number of Paragraphs: 2
# Number of arguments: 5
# Number of filtered-out arguments: 49
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Discrimination', 'PragerU', 'Speech', 'Sociology']
# ====
# Electoral College binding con
# Number of Paragraphs: 7
# Number of arguments: 14
# Number of filtered-out arguments: 18
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Student', 'Region', 'Northern Scotland', 'Community']
# ====
# Electoral College individual con
# Number of Paragraphs: 2
# Number of arguments: 8
# Number of filtered-out arguments: 10
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Village', 'Community service', 'Culture', 'Economy']
# ====
# Electoral College general con
# Number of Paragraphs: 7
# Number of arguments: 24
# Number of filtered-out arguments: 30
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Role', 'Region', 'Student', 'Community']
# ====
# National Health Care binding pro
# binding_pro_narrative of National Health Care is missing
# National Health Care individual pro
# individual_pro_narrative of National Health Care is missing
# National Health Care general pro
# Number of Paragraphs: 7
# Number of arguments: 217
# Number of filtered-out arguments: 687
# Number of key points: 0
# Number of clusters: 7
# Clusters: ['Role', 'Cost', 'Child', 'System', 'Efficiency', 'Human rights', 'Resource']
# ====
# National Health Care binding con
# binding_con_narrative of National Health Care is missing
# National Health Care individual con
# individual_con_narrative of National Health Care is missing
# National Health Care general con
# Number of Paragraphs: 7
# Number of arguments: 13
# Number of filtered-out arguments: 891
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Patient', 'Morality', 'Competition', 'Welfare']
# ====
# Free Trade binding pro
# Number of Paragraphs: 7
# Number of arguments: 343
# Number of filtered-out arguments: 224
# Number of key points: 0
# Number of clusters: 9
# Clusters: ['Voting', 'Policy', 'Economy', 'Treaty', 'Society', 'Price', 'Government', 'Corn Laws', 'Prosperity']
# ====
# Free Trade individual pro
# Number of Paragraphs: 7
# Number of arguments: 241
# Number of filtered-out arguments: 162
# Number of key points: 0
# Number of clusters: 7
# Clusters: ['Society', 'Comparative advantage', 'Role', 'Region', 'Peace', 'Film producer', 'Rights']
# ====
# Free Trade general pro
# Number of Paragraphs: 7
# Number of arguments: 603
# Number of filtered-out arguments: 394
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Principle', 'Voting', 'Investment', 'Nation', 'Consumer', 'Economy', 'Effectiveness', 'Commerce', 'Role', 'Society']
# ====
# Free Trade binding con
# Number of Paragraphs: 7
# Number of arguments: 74
# Number of filtered-out arguments: 493
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Poverty', 'History of slavery', 'Economy', 'Working class']
# ====
# Free Trade individual con
# Number of Paragraphs: 7
# Number of arguments: 51
# Number of filtered-out arguments: 352
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['National security', 'Conviction', 'Globalization', 'Farmer']
# ====
# Free Trade general con
# Number of Paragraphs: 7
# Number of arguments: 129
# Number of filtered-out arguments: 868
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Canadian sovereignty', 'History of slavery', 'Protectionism', 'Result', 'Manufacturing']
# ====
# Federal Reserve binding pro
# Number of Paragraphs: 7
# Number of arguments: 58
# Number of filtered-out arguments: 57
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Role', 'Biodiversity', 'Government', 'Endemism']
# ====
# Federal Reserve individual pro
# Number of Paragraphs: 7
# Number of arguments: 49
# Number of filtered-out arguments: 48
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Government', 'Bird migration', 'Gifted education', 'Area']
# ====
# Federal Reserve general pro
# Number of Paragraphs: 7
# Number of arguments: 109
# Number of filtered-out arguments: 108
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Role', 'Biodiversity', 'Area', 'Funding', 'Economy']
# ====
# Federal Reserve binding con
# Number of Paragraphs: 7
# Number of arguments: 16
# Number of filtered-out arguments: 99
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Constitutionality', 'Tax resistance', 'Bank', 'Hayek']
# ====
# Federal Reserve individual con
# Number of Paragraphs: 7
# Number of arguments: 14
# Number of filtered-out arguments: 83
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Inflation', 'Great Depression', 'Constitutionality', 'Debasement']
# ====
# Federal Reserve general con
# Number of Paragraphs: 7
# Number of arguments: 30
# Number of filtered-out arguments: 187
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Inflation', 'Constitutionality', 'Great Depression', 'Bank']
# ====
# Welfare binding pro
# Number of Paragraphs: 2
# Number of arguments: 4
# Number of filtered-out arguments: 7
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Grant (money)', 'Poverty', 'Moral responsibility', 'Acting']
# ====
# Welfare individual pro
# Number of Paragraphs: 7
# Number of arguments: 90
# Number of filtered-out arguments: 63
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Animal', 'Economy', 'Society', 'Poverty']
# ====
# Welfare general pro
# Number of Paragraphs: 7
# Number of arguments: 94
# Number of filtered-out arguments: 70
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Society', 'Common good', 'Animal', 'Child']
# ====
# Welfare binding con
# Number of Paragraphs: 2
# Number of arguments: 5
# Number of filtered-out arguments: 6
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Corruption', 'Conservatism', 'Single parent', 'Sex education']
# ====
# Welfare individual con
# Number of Paragraphs: 7
# Number of arguments: 33
# Number of filtered-out arguments: 120
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Poverty', 'Dependant', 'Disaster', 'Domestic violence']
# ====
# Welfare general con
# Number of Paragraphs: 7
# Number of arguments: 38
# Number of filtered-out arguments: 126
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Moral', 'Unemployment', 'Poverty', 'Corruption']
# ====
# Border Fence binding pro
# Number of Paragraphs: 7
# Number of arguments: 28
# Number of filtered-out arguments: 48
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Secure Fence Act of 2006', 'Plan', 'Illegal immigration', 'Construction']
# ====
# Border Fence individual pro
# Number of Paragraphs: 7
# Number of arguments: 31
# Number of filtered-out arguments: 54
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Fence', 'Voting interest', 'Illegal drug trade', 'Cross']
# ====
# Border Fence general pro
# Number of Paragraphs: 7
# Number of arguments: 61
# Number of filtered-out arguments: 106
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Secure Fence Act of 2006', 'Fence', 'Construction', 'Voting interest']
# ====
# Border Fence binding con
# error: sending POST to http://theme-extraction:8000/api/v1/theme/extract/ failed
# Border Fence individual con
# Number of Paragraphs: 4
# Number of arguments: 9
# Number of filtered-out arguments: 76
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Endangered species', 'Animal', 'Fence', 'Violence']
# ====
# Border Fence general con
# Number of Paragraphs: 7
# Number of arguments: 22
# Number of filtered-out arguments: 145
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Violence', 'Endangered species', 'Fence', 'The Ramblers']
# ====
# Medical Marijuana binding pro
# Number of Paragraphs: 7
# Number of arguments: 194
# Number of filtered-out arguments: 287
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Medicine', 'Recreation', 'Background check', 'Funding', 'Legislation', 'Disease']
# ====
# Medical Marijuana individual pro
# Number of Paragraphs: 7
# Number of arguments: 132
# Number of filtered-out arguments: 263
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Medicine', 'Violent crime', 'Patient', 'Child', 'Health care']
# ====
# Medical Marijuana general pro
# Number of Paragraphs: 7
# Number of arguments: 329
# Number of filtered-out arguments: 560
# Number of key points: 0
# Number of clusters: 9
# Clusters: ['Recreation', 'Patient', 'Advocate', 'Intraocular pressure', 'Voting', 'Child', 'Funding', 'Legalization', 'Therapy']
# ====
# Medical Marijuana binding con
# Number of Paragraphs: 7
# Number of arguments: 60
# Number of filtered-out arguments: 421
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Legalization', 'Dör', 'Ban (law)', 'Prohibition']
# ====
# Medical Marijuana individual con
# Number of Paragraphs: 7
# Number of arguments: 56
# Number of filtered-out arguments: 339
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Abuse', 'Risk', 'Brain', 'Tobacco smoking']
# ====
# Medical Marijuana general con
# Number of Paragraphs: 7
# Number of arguments: 117
# Number of filtered-out arguments: 772
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Prohibition of drugs', 'Legalization', 'Brain', 'Result', 'Addiction']
# ====
# Flat Tax binding pro
# Number of Paragraphs: 7
# Number of arguments: 45
# Number of filtered-out arguments: 424
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Repeal', 'Designer', 'Business', 'System']
# ====
# Flat Tax individual pro
# Number of Paragraphs: 7
# Number of arguments: 38
# Number of filtered-out arguments: 431
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['System', 'Economic inequality', 'Fuel economy in automobiles', 'Motorcycle']
# ====
# Flat Tax general pro
# Number of Paragraphs: 7
# Number of arguments: 85
# Number of filtered-out arguments: 886
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['System', 'Consumption (economics)', 'Business', 'Attractiveness']
# ====
# Flat Tax binding con
# Number of Paragraphs: 7
# Number of arguments: 75
# Number of filtered-out arguments: 394
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Constitutionality', 'Economy', 'Job', 'Inefficiency']
# ====
# Flat Tax individual con
# Number of Paragraphs: 7
# Number of arguments: 103
# Number of filtered-out arguments: 366
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Policy', 'Economy', 'Constitution of Connecticut', 'Investment', 'Cost']
# ====
# Flat Tax general con
# Number of Paragraphs: 7
# Number of arguments: 185
# Number of filtered-out arguments: 786
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Economy', 'Policy', 'Job', 'Constitutionality', 'Consumer', 'Manufacturing']
# ====
# Legalized Prostitution binding pro
# Number of Paragraphs: 7
# Number of arguments: 323
# Number of filtered-out arguments: 1879
# Number of key points: 0
# Number of clusters: 8
# Clusters: ['Netherlands', 'Adult', 'Government', 'Drug', 'Brothel', 'Constitutionality', 'Gambling', 'Woman']
# ====
# Legalized Prostitution individual pro
# Number of Paragraphs: 7
# Number of arguments: 38
# Number of filtered-out arguments: 217
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Regulation', 'Gambling', 'Rape', 'Crime']
# ====
# Legalized Prostitution general pro
# Number of Paragraphs: 7
# Number of arguments: 363
# Number of filtered-out arguments: 2126
# Number of key points: 0
# Number of clusters: 9
# Clusters: ['Office', 'Sex worker', 'Drug', 'Rural area', 'Regulation', 'Libertarianism', 'Brothel', 'Legalization', 'Tourism']
# ====
# Legalized Prostitution binding con
# Number of Paragraphs: 7
# Number of arguments: 583
# Number of filtered-out arguments: 1619
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Criminal code', 'Smuggling', 'Woman', 'Area', 'Human trafficking', 'Brothel', 'Ban (law)', 'HIV/AIDS', 'Society', 'Crime']
# ====
# Legalized Prostitution individual con
# Number of Paragraphs: 7
# Number of arguments: 101
# Number of filtered-out arguments: 154
# Number of key points: 0
# Number of clusters: 5
# Clusters: ['Harm', 'Violence against women', 'Traffic', 'Abuse', 'Woman']
# ====
# Legalized Prostitution general con
# Number of Paragraphs: 7
# Number of arguments: 696
# Number of filtered-out arguments: 1793
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Woman', 'HIV/AIDS', 'Morality', 'England and Wales', 'Child', 'Trafficking of children', 'Crime', 'Sin', 'Society', 'Sexually transmitted infection']
# ====
# Socialism binding pro
# Number of Paragraphs: 7
# Number of arguments: 77
# Number of filtered-out arguments: 126
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Economy', 'Constitution', 'Nation', 'System']
# ====
# Socialism individual pro
# Number of Paragraphs: 7
# Number of arguments: 60
# Number of filtered-out arguments: 62
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Moral', 'Peace', 'Productive forces', 'Happiness']
# ====
# Socialism general pro
# Number of Paragraphs: 7
# Number of arguments: 147
# Number of filtered-out arguments: 210
# Number of key points: 0
# Number of clusters: 6
# Clusters: ['Society', 'Poverty', 'Individualism', 'Peace', 'Moral', 'Social equality']
# ====
# Socialism binding con
# Number of Paragraphs: 7
# Number of arguments: 61
# Number of filtered-out arguments: 142
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Decision-making', 'System', 'Failure', 'Tyrant']
# ====
# Socialism individual con
# Number of Paragraphs: 7
# Number of arguments: 28
# Number of filtered-out arguments: 94
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Wealth', 'Economy', 'Liberty', 'Failure']
# ====
# Socialism general con
# Number of Paragraphs: 7
# Number of arguments: 99
# Number of filtered-out arguments: 258
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['System', 'Failure', 'Capitalism', 'Slavery']
# ====
# Global Warming binding pro
# Number of Paragraphs: 7
# Number of arguments: 429
# Number of filtered-out arguments: 475
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Temperature', 'Greenhouse gas', 'Species', 'Deforestation', 'Threat', 'Permafrost', 'Sea level rise', 'Pollution', 'Agriculture', 'Global cooling']
# ====
# Global Warming individual pro
# Number of Paragraphs: 7
# Number of arguments: 720
# Number of filtered-out arguments: 873
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Sea level rise', 'Threat', 'Ecosystem', 'Greenhouse gas', 'Earthquake', 'Risk', 'Tropical cyclone', 'Water', 'Coast', 'Fossil fuel']
# ====
# Global Warming general pro
# Number of Paragraphs: 7
# Number of arguments: 1175
# Number of filtered-out arguments: 1388
# Number of key points: 0
# Number of clusters: 10
# Clusters: ['Sea level rise', 'Greenhouse gas', 'Species', 'Temperature', 'Tropical cyclone', 'Population', 'Threat', 'Coral reef', 'Fossil fuel', 'Technology']
# ====
# Global Warming binding con
# Number of Paragraphs: 7
# Number of arguments: 14
# Number of filtered-out arguments: 890
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Hoax', 'Carbon dioxide', 'Rethinking', 'Organization']
# ====
# Global Warming individual con
# Number of Paragraphs: 7
# Number of arguments: 43
# Number of filtered-out arguments: 1550
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Threat', 'Hoax', 'Ecology', 'Life']
# ====
# Global Warming general con
# Number of Paragraphs: 7
# Number of arguments: 59
# Number of filtered-out arguments: 2504
# Number of key points: 0
# Number of clusters: 4
# Clusters: ['Threat', 'Hoax', 'Grape', 'Ocean']
# ====

# %%
topic_and_narratives_df1 = pd.DataFrame([[topic,
                                    narrative_name.split('_')[1],
                                    narrative_name.split('_')[0],
                                    str(narrative)] for topic, topic_info in topic_narratives.items() for narrative_name, narrative in topic_info.items() if 'narrative' in narrative_name],
                                    columns=['topic', 'stance', 'moral_class', 'narrative'])

# %%
topic_and_narratives_df1.head()
# Out:
#           topic stance moral_class  \
# 0  Gay Marriage    pro     binding
# 1  Gay Marriage    con     binding
# 2  Gay Marriage    pro  individual
# 3  Gay Marriage    con  individual
# 4  Gay Marriage    pro     general
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       narrative
# 0                                                                                                      Greetings all. The crowd has contributed 886 arguments in support of the claim that Gay Marriage. Following is a summary of its thoughts. \n\nThere are four issues the crowd has raised, supporting the perception that Gay Marriage: majority, legalization, lgbt and men. \n\nRegarding majority.  The majority of Catholics support gay marriage.   In the United States and Spain, it support gay marriage, followed by France at 43% support.   Public opinion polls currently indicate majority support for gay marriage among the people of the Commonwealth.   Polls have shown that a majority of the Swiss population supports same-sex marriage, with the most recent one finding 75% support.  In 2012 a poll by MaltaToday showed that 41% of Maltese supported same-sex marriage, with support increasing to 60% amongst the 18-35 age group. \n\nNext, a few words about legalization.  Martin O'Malley, the Governor of the US state of Maryland, signs a law legalizing gay marriage in that state.   Keep - legalizing gay marriage in the region has become an important focal point of the same-sex marriage movement.  Singer, whose son Andrew married his husband Corey Morris in a same-sex marriage in Massachusetts in 2009, has also financially supported the legalization of gay marriage in New York, and Maryland.  In Quinn's 2013 State of the State address, he declared his commitment to the legalization of gay marriage.  \n\nThe next issue is lgbt.  Spearman, who is lesbian herself, supported gay marriage and abortion.   The establishment of same-sex marriage is associated with a significant reduction in the rate of attempted suicide among children, with the effect being concentrated among children of a minority sexual orientation.   60% of Catholics favor allowing gay and lesbian couples to marry legally, compared to 55% of Americans as a whole.  \n\nThe last issue is men.  A study of the conditions for gay men indicates that gay men in the Danish Defence show strength and are respected.   Gay activist Jonathan Rauch has argued that marriage is good for all men, whether homosexual or heterosexual, because engaging in its social roles reduces men's aggression and promiscuity.   Gay men make better fighters, because, having no family, they are closer to their comrades.  \n\nFor all these reasons, the crowd is supporting the notion that Gay Marriage. Thanks for tuning in.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                               Hello everybody. The crowd posted 886 arguments, opposing the claim that Gay Marriage. Here is a summary. \n\nThere are four issues the crowd has raised, opposing the perception that Gay Marriage: bans, bestiality, wrongs and proposition 8. \n\nRegarding bans.  The 2012 Minnesota constitutional amendment to ban gay marriage.  In 2005, she led a march to her father's gravesite and at the same time called out for a constitutional ban on gay marriage.  Hunter opposed same-sex marriage, and proposed a constitutional amendment to ban same-sex marriage.  According to a poll, conducted in February 2005 by Research 2000 for the Concord Monitor, 51% of likely voters in the state supported a federal constitutional amendment to ban same-sex marriage. \n\nNext, a few words about bestiality.  Gay marriage will lead to legalized bestiality.   It is a threat to all marriage.   Allowing gay marriage would lead to legal bestiality.   Conservatives use the argument that legalizing gay marriage will ultimately lead to legalized bestiality.   Gay behavior should be a criminal offense.  \n\nThe next issue is wrongs.  Gay marriage is wrong.   Marriage is the wrong goal, as it is an institution rooted in sexism.   Homosexual marriage is wrong, then that would seem to be pretty strong evidence that it is wrong.   Sex outside of marriage is sinful, and therefore gay sex is sinful.  \n\nThe last issue is proposition 8.  Proposition 8, which banned gay marriage within California.   Korean-Americans, due to their Republican and Christian leanings, overwhelmingly supported California's constitutional gay marriage ban, Proposition 8.  In 2008, Blake's President Brian Rule donated $10,000 to support California Proposition 8, which temporarily banned gay marriage in California.  In October 2008, he appeared alongside Rev. Jim Franklin of Cornerstone Church, to oppose gay marriage and support Proposition 8, the California same-sex marriage ban.  \n\nFor all these reasons, the crowd is opposing the notion that Gay Marriage. Thanks for tuning in.
# 2                                                                 Greetings all. The crowd has contributed 420 arguments in support of the claim that Gay Marriage. Following is a summary of its thoughts. \n\nThere are four issues that will be addressed. The first will explain that Gay marriage doesn't damage children. Then, the topics of lgbt rights, lgbt and bans will be elaborated on. \n\nRegarding children.  Adopting same-sex marriage would be likely to improve the well-being of gay and lesbian households and their children.   By fostering better life decisions and stronger relationship skills, marriage programs can increase child well-being and adult happiness and reduce child poverty and welfare dependence.  \n\nNext, a few words about lgbt rights.  Some representatives in the Diocese of Uruguay have supported gay and lesbian rights.   Lesbian, gay and bisexual people should be regarded as valued members of society who have exactly similar rights and responsibilities as all other citizens.  In 2011, Clinton took a similar position on LGBT rights in a speech to the United Nations on International Human Rights Day, declaring "gay rights are human rights, and human rights are gay rights.". \n\nThe next issue is lgbt. According to the International Lesbian, Gay, Bisexual, Trans and Intersex Association, Sweden is one of Europe's most gay-friendly countries, with extensive legislation protecting gay and lesbian rights, including anti-discrimination law and same-sex marriage legislation.  The CCAR supported the right of gay and lesbian couples to share fully and equally in the rights of civil marriage and opposed governmental efforts to ban gay and lesbian marriage.   It oppose governmental efforts to ban gay and lesbian marriage.   A October 2012 Washington Post poll found wide support for gay marriage among Florida voters, reflecting the changing attitudes toward LGBT residents of the state.  \n\nThe last issue is bans.  Bans on gay marriage violate Equal Protection and substantive due process rights.   The court finds the prohibition of gay marriage unconstitutional because it denies dignity and equality of all individuals.  When the Supreme Court took up the issue in 2015, Sanders issued a statement reaffirming his support, saying gay Americans in every state should be allowed to marry: "Of course all citizens deserve equal rights. \n\nFor all these reasons, the crowd is supporting the notion that Gay Marriage. Thanks for tuning in.
# 3                                                                                                                                                                                                                    Hello everybody. The crowd posted 420 arguments, opposing the claim that Gay Marriage. Here is a summary. \n\nThere are four issues the crowd has raised, opposing the perception that Gay Marriage: damage, societies, children and gay. \n\nRegarding damage.  Plural marriage would inflict terrible damage, that he ran the risk of wrecking his marriage and alienating his followers.   A gay bill because it is damaging to the survival of the country.   Gay marriage was evil.   It is wrong.   Gay marriage and incest are bad for society.  \n\nNext, a few words about societies.  Same-sex marriage would harm society or the institution of marriage.   It is a form of "extreme human rights" and "will create social problems.   A functioning marriage culture serves to protect political liberty and foster limited government.   Marriage is the most important social institution in our society.  It is considered the source of inner knowledge of life according to the Ayyavazhi ideas. \n\nThe next issue is children.  Gay people are more likely to be abused as children.  In 2005, he resurrected his legislation that would ban gay people from adopting children, claiming that gay people were more prone to violence, alcoholism, and suicide.  The gay parade doesn't have any benefits because it provokes hatred among intolerant people is absurd.   The plaintiffs proved how Berk posted answers to questions about homosexuality that said gay people were "sick," "disordered," and "broken" and that gay people were likely to become alcoholics, abuse children, and die of AIDS.  \n\nThe last issue is gay.  GLAAD describes the association of homosexuality with pedophilia or child abuse as an attempt to "insinuate that lesbians and gay men pose a threat to society, to families, and to children in particular.".   Russia's gay propaganda law encourages homophobia, reinforces prejudice and violates the right to freedom of speech.   Gay and lesbian youth can develop severe forms of depression and anxiety as they grow up.   The United Nations views forced marriage as a form of human rights abuse, since it violates the principle of the freedom and autonomy of individuals.  \n\nFor all these reasons, the crowd is opposing the notion that Gay Marriage. Thanks for tuning in.
# 4  Greetings all. The crowd has contributed 1355 arguments in support of the claim that Gay Marriage. Following is a summary of its thoughts. \n\nThere are four issues the crowd has raised, supporting the perception that Gay Marriage: vote, unconstitutional, lgbt rights and Barack Obama. \n\nRegarding vote.  An August 2012 Public Policy Polling survey found that a plurality of voters in the state supported same-sex marriage.   A October 2012 Washington Post poll found wide support for gay marriage among Florida voters, reflecting the changing attitudes toward LGBT residents of the state.  In 2012 a poll by MaltaToday showed that 41% of Maltese supported same-sex marriage, with support increasing to 60% amongst the 18-35 age group. \n\nNext, a few words about unconstitutional.  Bans on same-sex marriage are unconstitutional, effectively legalizing same-sex marriage in the United States.   A federal ban against gay marriage is unconstitutional, as it interferes with a state's right to define marriage.  In 2014, he ruled that Pennsylvania's 1996 ban on same-sex marriage was unconstitutional. \n\nThe next issue is lgbt rights.  In a speech before the United Nations Human Rights Council in December 2011, Clinton said that "Gay rights are human rights" and that the U.S. would advocate for gay rights and legal protections of gays abroad.   In an interview on The Howard Stern Show, he reaffirmed his support of gay rights, including in marriage and military service, humorously stating he would have gladly served alongside homosexuals when he was in the Navy as they would have provided less competition for women.   Polls show that public belief that AIDS is the nation's "most urgent health problem" has declined from 38% to 7% since Sexual Ecology was published, and support for gay rights is at an all time high.  \n\nThe last issue is Barack Obama. During an ABC News interview in 2012, Barack Obama expressed his support for gay marriage, becoming the first US President to do so.  Polis has also credited President Obama for openly endorsing gay marriage calling it "welcome news to American families.".  In 2012, President Barack Obama voiced support for gay marriage, and in the November elections, three states voted to legalize gay marriage at the ballot box for the first time in history while an attempt to restrict same-sex marriage was rejected. \n\nFor all these reasons, the crowd is supporting the notion that Gay Marriage. Thanks for tuning in.

# %%
topic_and_narratives_df1.to_csv(data_path + 'top_20_big_issues_narratives.csv')

# %% [markdown]
# ### Analyse morals of generated narratives:

# %%
data = pickle.load(open(data_path + 'moral_narratives_via_classifier_for_top_20_big_issues.pkl', 'rb'))

# %%
speech = data['Gay Marriage']['individual_pro_narrative']
[x.text for x in speech.arguments.values()]
# Out:
# ['"Gay proved to be an enormous help," wrote Minnelli later.',
#  "14 - In Bishop v. Oklahoma, U.S. District Court Judge Terence Kern ruled that the Oklahoma's ban on gay marriage violates the equal protection clause of the U.S. constitution for homosexual couples.",
#  "20 - In Kitchen v. Herbert, U.S. District Judge Robert Shelby ruled that the Utah's ban on gay marriage violates the due process and equal protection under the 14th Amendment for gay and lesbian couples [REF].",
#  "25 \nIn Baskin v. Bogan, U.S. District Court Judge Richard Young ruled that Indiana's statutory ban on gay marriage violates the equal protection clause of the U.S. Constitution [REF].",
#  "6 - In Wolf v. Walker, U.S. District Court Judge Barbara Crabb ruled that Wisconsin's constitutional and legislative ban on gay marriage violates the due process clause of the U.S. constitution, and discriminates on the basis of sexual orientation, violating the equal protection clause [REF].",
#  "9 - In a combined case of Brinkman v. Long and McDaniel-Miccio v. Hickenlooper, State District Court Judge C. Scott Crabtree ruled that Colorado's ban on gay marriage violates the equal protection and due process of the U.S. Constitution.",
#  'A October 2012 Washington Post poll found wide support for gay marriage among Florida voters, reflecting the changing attitudes toward LGBT residents of the state',
#  'A October 2012 Washington Post poll found wide support for gay marriage among Florida voters, reflecting the changing attitudes toward LGBT residents of the state.',
#  'A poll commissioned by LGBT outlet PinkNews found 98% in support of marriage equality [REF].',
#  "A poll commissioned by PinkNews and answered by more than 800 of their readership found 98% in support of marriage equality, with many comments calling for Summerskill's resignation [REF].",
#  'A separate study shows that, in the United States, the younger generation is more supportive of gay rights than average, and that there is growing support for LBGT rights.',
#  "A spokesperson for DignityUSA suggested that Catholic support for gay marriage was due to the religion's tradition of social justice, the importance of the family, and better education [REF].",
#  "According to a Gay Japan News 2009 election questionnaire, he supported legalization of gay marriage in Japan and indicated a desire to put support for gay rights into the Democratic Party of Japan's party platform [REF].",
#  "According to the International Lesbian, Gay, Bisexual, Trans and Intersex Association (ILGA), Sweden is one of Europe's most gay-friendly countries, with extensive legislation protecting gay and lesbian rights, including anti-discrimination law and same-sex marriage legislation [REF].",
#  'According to the National Journal, he "has voiced support for gay marriage, abortion rights, and environmental protections."[REF] .',
#  'Also in 1990, Merrill College at UC Santa Cruz established Vito Russo House to promote Gay, Lesbian, Bisexual and Transgender awareness and provide a safe and comfortable living environment for queer, straight-supportive and all students who value and appreciate diversity.',
#  'As President, George H. W. Bush signed legislation that extended gay rights.',
#  'Barkley is an outspoken supporter of gay rights.',
#  'Bartlett has also campaigned for gay rights.',
#  'Bell is a lifelong proponent of gay rights.',
#  'Bold Nebraska has also advocated for gay rights [REF].',
#  'By fostering better life decisions and stronger relationship skills, marriage programs can increase child well-being and adult happiness and reduce child poverty and welfare dependence',
#  'Campbell has generally supported gay rights and abortion [REF].',
#  'Clinton stated she fully supported civil unions that would have the full equality and benefits of heterosexual marriage.',
#  "Colorado's ban on gay marriage violates the equal protection and due process of the",
#  'Connolly supports gay rights, having campaigned against the Marshall-Newman Amendment to the Virginia Constitution, which banned all gay unions from being performed or recognized in Virginia [REF].',
#  'Departments within the university also expressed their support in advocating for gay rights and the Gay Alliance of Students.',
#  'During 2006, the Supreme Court of New Jersey ordered the state to provide the rights and benefits of marriage to gay and lesbian couples.',
#  'FT2 18:32, Dec 16, 2004 (UTC)\nIts funny; APA has publically supported gay marriage, saying how homosexuality is normal and that legalizing it is important for the mental health of gay teens and such.',
#  "Field is also an advocate for gay rights and won the Human Rights Campaign's Ally for Equality Award in 2012.",
#  'Five different studies have shown that gay characters appearing on TV decreases the prejudice among viewers [REF].',
#  'Former UN Secretary-General Ban Ki-moon supported a move towards greater respect for gay rights.',
#  "Furthermore, Luxuria outlined her long-term support for full gay marriage rights, comparable with Spain's implementation of the law [REF].",
#  "Gay Prom offers a safe space for LGBTQIA2-S and allies to experience the full 'prom experience' they were not given in their own high schools",
#  'Gay Science might help us to develop a methodology that can be practiced within performance by interweaving paradigms and researching different types performance',
#  'Gay is Good" for the gay civil rights movement',
#  'Gay is Good: The Moral Case for Marriage Equality and More',
#  "Gay marriage doesn't damage children",
#  'Gay marriage is a blessing not a curse',
#  'Gay proved to be an enormous help',
#  'Gore also promised to work toward expanding gay rights, and supports legislation such as the Hate Crime Prevention Act that would broaden the definition of hate crimes to include crimes committed against gay people [REF].',
#  'Guadagnino is also a supporter of gay rights.',
#  'However, Collins later clarified her view in support of LGBT marriage equality [REF].',
#  "Hull served on the Board of the Women's Sports Foundation, and he endowed the first Chair in Women's Studies at his alma mater, University of California, Santa Barbara\nLGBT causes Blair Hull is a strong voice in favor of gay rights and greater equality.",
#  'In 1970, Ito announced in one of his publications that he was going to launch a gay magazine, in order to reduce prejudices in the mainstream cultures and encourage gay people that they deserve better lives and brighter future.',
#  'In 2011, Clinton took a similar position on LGBT rights in a speech to the United Nations on International Human Rights Day, declaring "gay rights are human rights, and human rights are gay rights."[REF] .',
#  "In 2015, St Mark's Cathedral in Bangalore, a congregation of the CSI, hosted a forum on preventing homophobia, and the Rev. Vincent Rajkumar advocated for the support of gay rights [REF].",
#  'In June 2014, 20,000 supporters demonstrated in favor of gay rights.',
#  'In a speech before the United Nations Human Rights Council in December 2011, Clinton said that "Gay rights are human rights" and that the U.S. would advocate for gay rights and legal protections of gays abroad [REF].',
#  'In an interview on The Howard Stern Show, he reaffirmed his support of gay rights, including in marriage and military service, humorously stating he would have gladly served alongside homosexuals when he was in the Navy as they would have provided less competition for women [REF].',
#  'In fact, polls show that public belief that AIDS is the nation\'s "most urgent health problem" has declined from 38% to 7% since Sexual Ecology was published, and support for gay rights is at an all time high [REF].',
#  'In the 1980s, the Radical Democratic Green Party expressed support for gay rights, including the work of a group of transgender people to protest police brutality.',
#  "Jackson has commended Obama's 2012 decision to support gay marriage and has compared the fight for same-sex marriage to fight against slavery and the anti-miscegenation laws that once prevented interracial marriage [REF].",
#  "Jackson supports gay rights, introducing ill-fated legislation in 2013 to change Arizona's state Constitution which defined marriage as between one man and one woman [REF].",
#  "Jong supports LGBT rights and legalization of same-sex marriage and she claims that 'Gay marriage is a blessing not a curse.",
#  'Keating is a supporter of gay rights.',
#  'Kendall is a strong supporter of LGBT rights and voted for gay marriage in 2013.',
#  'King B-Fine, a Rastafari Reggae artist born in Jamaica, openly supports gay rights.',
#  "King's widow Coretta publicly said that she believed her husband would have supported gay rights [REF].",
#  'Lewis has spoken out in support of gay rights and national health insurance [REF].',
#  'Lindgren was possibly the first elected official in North Dakota to express support for gay rights in North Dakota.',
#  'Lots of UK businesses gave their support to the gay marriage bill and there is also the Stonewall equality index too for a gay-friendly business directory.',
#  'Lovato is an active supporter of gay rights.',
#  'Lovato later said: "I believe in gay marriage, I believe in equality.',
#  'MacFarlane is passionate about his support for gay rights.',
#  'Macias added that Jackson supports gay causes and has been persistently active in portraying equality among the gay community and would not approve the edit.',
#  'Many left-wing political parties, namely the Democratic Left Alliance, Labour United, the Social Democracy Party, Your Movement and the Modern party, have expressed support for the gay rights movement.',
#  'McCain has championed gay rights, and she has commented that the cause of the gay community for equality is "one of the ones closest to my heart."',
#  'McClanahan was a supporter of gay rights, including advocating for same-sex marriage in the United States.',
#  'Meyers supports gay rights [REF].',
#  'Morrison notes that Lawrence\'s sex-positive predecessor Scott O\'Hara\'s books espoused that "the gay body could be (and should be) a source of pleasure" [REF].',
#  'Nabagasera has continued the fight for gay rights in Uganda.',
#  'Nixon is heterosexual but marched to express her support for gay and lesbian causes, stating "What I\'m doing is supporting decent and reasonable people who want to get on with their lives, and they have been treated appallingly previously by the Police, and I\'m prepared to do something about it.',
#  "On Hormel's account, Clinton had been the first President to advocate gay rights, push for AIDS funding, support gay and lesbian civil rights legislation, and appoint open LGBT people to his Administration.",
#  "On June 19, 2007 O'Donnell ushered the Marriage Equality Act, a bill that would have legalized gay marriage in New York State, to passage by a vote of 85-61.",
#  'On October 10, 2008, Connecticut courts ruled that the ban of gay marriage violated citizens rights guaranteed to them by the constitution.',
#  'Paraskeva has been a strong advocate for gay and lesbian rights in the United Kingdom.',
#  'Perot is pro-choice, supports gay rights, stricter gun controls such as an assault rifle ban and increased research in AIDS [REF].',
#  'Reed also has supported gay rights, voting against a proposed constitutional amendment to ban gay marriage, while voting in favor of measures that prevent job discrimination and hate crimes against LGBT [REF].',
#  'Referencing Friedrich Nietzsche, he also suggests that Gay Science might help us to develop a methodology that can be practiced within performance by interweaving paradigms and researching different types performance.',
#  'Schmidt voiced his support for gay rights at a meeting of the Log Cabin Republicans, a gay Republican group.',
#  "Scientific literature indicates that parents' financial, psychological and physical well-being is enhanced by marriage and that children benefit from being raised by two parents within a legally recognized union (either a mixed-sex or same-sex union).",
#  'September 2002: The association filed an amicus brief in Goodridge v. Department of Public Health in support of gay marriage as a civil rights issue stating that discrimination against gays and lesbians is unacceptable and unconstitutional [REF].',
#  'She continued to address rights concerns in a December 2011 speech a few days later before the United Nations Human Rights Council, saying that the U.S. would advocate for gay rights abroad and that "Gay rights are human rights" and that "It should never be a crime to be gay."[REF]',
#  'Some representatives in the Diocese of Uruguay have supported gay and lesbian rights [REF].',
#  'Springsteen is an activist for LGBT rights and has spoken out many times as a strong supporter of gay marriage.',
#  "That case helped turn the tide toward marriage equality in New Mexico and just a few months later, the state's Supreme court ruled to legalize gay marriage, making New Mexico the 17th state to do so [REF].",
#  'The CCAR supported the right of gay and lesbian couples to share fully and equally in the rights of civil marriage and opposed governmental efforts to ban gay and lesbian marriage',
#  'The CCAR supported the right of gay and lesbian couples to share fully and equally in the rights of civil marriage and opposed governmental efforts to ban gay and lesbian marriage, stating, "this is a matter of civil law and is separate from the question of rabbinic officiation at such marriages." .',
#  'The Central Conference of American Rabbis support the right of gay and lesbian couples to share fully and equally in the rights of civil marriage, and \nThat the CCAR oppose governmental efforts to ban gay and lesbian marriage.',
#  'The Libertarian Party supported gay rights from its founding in 1971.',
#  'The Raelian movement defends the rights and freedoms of gays and lesbians, recognises gay marriage and ordains gay clergy [REF].',
#  'The Roberts administration was known for its strong support of gay rights and appointed women to positions in state government.',
#  'The Washington Blade endorsed Mara, noting his support for same-sex marriage and other stands in support of civil rights [REF].',
#  'The church advocated for gay rights in the 1980s and 1990s [REF].',
#  'The court finds the prohibition of gay marriage unconstitutional because it denies dignity and equality of all individuals [REF].',
#  'The entire time Representative McCollum has been in office, she has supported gay civil rights [REF].',
#  'The establishment of same-sex marriage is associated with a significant reduction in the rate of attempted suicide among children',
#  'The purpose of such prayer services, according to the Finnish Lutheran synod and archbishop, is to take a "clear and unequivocal stance in support of gay and lesbian couples" [REF].',
#  'West herself was an avid supporter of gay rights during her entire life.',
#  'West regarded talking about sex as a basic human rights issue, and was also an early advocate of gay rights.',
#  'What is more, the distinctive style of gay masculinity is of great social benefit',
#  'When the Supreme Court took up the issue in 2015, Sanders issued a statement reaffirming his support, saying gay Americans in every state should be allowed to marry: "Of course all citizens deserve equal rights.',
#  'a Nation for the gay people, it would help thousands of gays suffering from government persecution',
#  "a few months later, the state's Supreme court ruled to legalize gay marriage",
#  'a fight for gay marriage was "a fight for all our rights',
#  'adopting same-sex marriage would be likely to improve the well-being of gay and lesbian households and their children',
#  'adult gay life is pretty awesome',
#  'bans on gay marriage violate Equal Protection and substantive due process rights',
#  'civil partnerships give gay people clear civil rights and recognition as people committed to one another',
#  'gay Americans in every state should be allowed to marry: "Of course all citizens deserve equal rights',
#  'gay love is good for us and for the rest of the world too',
#  'gay men could be sexual and affectionate while dramatically reducing the risk of contracting or spreading HIV',
#  'gay sex can also strengthening of marriage bonds and becoming one flesh',
#  'has supported the legalization of gay marriage and reducing discrimination against gays and lesbians',
#  'heterosexual marriage has been or is the only lawful union between two people that was or is fully recognized and subsequently given full benefits in many countries',
#  'legalizing gay marriage might help to lower the contact rate',
#  'lesbian, gay and bisexual people should be regarded as valued members of society who have exactly similar rights and responsibilities as all other citizens',
#  'marriage is not only an important life goal, but also, a goal that will happen soon after-if not during-their college years',
#  'same-sex marriage improves the health of gay men overall',
#  'the CCAR oppose governmental efforts to ban gay and lesbian marriage',
#  "the Oklahoma's ban on gay marriage violates the equal protection clause of the U.S. constitution for homosexual couples",
#  'the ban of gay marriage violated citizens rights guaranteed to them by the constitution']

# %%
speech = data['Gay Marriage']['binding_pro_narrative']
[x.text for x in speech.arguments.values()]
# Out:
# ['"After all, Islam despises homosexuality-and this Muslim-friendly gay bar would help mend fences", Gutfeld said [REF].',
#  "(BBC) (BBC) (Daily Mail)\nAlbania's Prime Minister Sali Berisha indicates he may legalise gay marriage in the country.",
#  "(CNN)\nMartin O'Malley, the Governor of the US state of Maryland, signs a law legalizing gay marriage in that state.",
#  '(John Edwards supported civil unions, while Elizabeth Edwards had stated that she supported gay marriage.)',
#  "(Reuters) (Washington Post)\nSame-sex marriage in the United States: The New York State Supreme Court rules that the state's ban on same-sex marriage violates the state constitution.",
#  "(The Guardian)\nA Virginia judge rules the state's prohibition of gay marriage unconstitutional.",
#  ', Islam despises homosexuality-and this Muslim-friendly gay bar would help mend fences',
#  "20 - The Supreme Court of California agrees to hear arguments for a possible overturn of Proposition 8. \n24 - A lower court in the U.S. state of Florida declares that the state's ban on adoption by gay couples is unconstitutional [REF].",
#  "23 - In Obergefell v. Wymyslo, Federal Court Judge Timothy Black ruled that Ohio's ban on gay marriage is unconstitutional.",
#  '23 - Voters in the Republic of Ireland approved an amendment to their constitution to legalize marriage for gay and lesbian couples.',
#  '50% of Catholics support gay marriage (compared to 45% of Protestants, and 66% of people in the UK as a whole) [REF].',
#  '60% of Catholics favor allowing gay and lesbian couples to marry legally, compared to 55% of Americans as a whole.',
#  "A 2000 study found that lifting the ban on gay service did not have any negative effects on the ADF's morale, effectiveness or recruitment and retention, and may have led to increased productivity and improved working environments.",
#  'A Eurobarometer survey published in December 2006 showed that 58% of Luxembourgers surveyed supported same-sex marriage and 39% supported adoption by same-sex couples.',
#  'A European Union member poll conducted in 2015 indicated that 91% of the Netherlands supported same-sex marriage, which was the highest amount of support during that time [REF].',
#  'A July 2011 Public Policy Polling survey found that a plurality of voters in the state supported same-sex marriage.',
#  'A June 2018 survey found that 58% of Israelis were in favour of same-sex marriage.',
#  "A Virginia judge rules the state's prohibition of gay marriage unconstitutional",
#  "A federal court ruled South Carolina's ban on same-sex marriage unconstitutional on November 12, with implementation of that decision stayed until noon on November 20.",
#  "A federal judge rules that South Dakota's ban on same-sex marriage is unconstitutional, and immediately stays the ruling [REF].",
#  'A large majority of Luxembourgers support same-sex marriage.',
#  'A study of the conditions for gay men indicates that gay men in the Danish Armed Forces show strength and are respected [REF].',
#  'A study of the conditions for gay men indicates that gay men in the Danish Defence show strength and are respected [REF].',
#  'Additionally, polls have shown that a majority of the Swiss population supports same-sex marriage, with the most recent one finding 75% support [REF].',
#  'After that survey went ahead and found most Australians support same-sex marriage, Cormann chose to vote in favour of the bill legalising same-sex marriage.',
#  'After the Taiwanese Constitutional Court ruled in May 2017 that banning same-sex marriage is unconstitutional, attitudes towards the legalisation of such marriages were largely positive on the popular Chinese social media site of Sina Weibo.',
#  "Albania's Prime Minister Sali Berisha indicates he may legalise gay marriage in the country",
#  "Alekh's mother, Vasundhara (Seema Kapoor) thinks that marriage can help Alekh to get better.",
#  'An August 2012 Public Policy Polling survey found that a plurality of voters in the state supported same-sex marriage.',
#  'And Lawrence takes it to the next level, "the gay body not only pleasurable, but profitable" [REF].',
#  "Arizona's law banning gay marriage was unconstitutional",
#  'As of 2014, gay marriage is legal in Nevada',
#  'As of 2014, gay marriage is legal in Nevada.',
#  'As public opinion polls currently indicate majority support for gay marriage among the people of the Commonwealth, it is likely that the issue is settled in Massachusetts.',
#  'As well as contributing to private initiatives, Singer also actively seeks to persuade other Republicans to support gay marriage [REF].',
#  'Australia (ranked 8th) and Taiwan (ranked 33rd) both legalised gay marriage in 2017.',
#  'Australia is recognised as one of the most gay-friendly countries in the world,[REF][REF][REF] with opinion polls and the Australian Marriage Law Postal Survey indicating widespread popular support for same-sex marriage [REF].',
#  'Barr has stated she supports gay marriage [REF].',
#  'Beeching began speaking out in favour of gay marriage beginning in December 2013 [REF].',
#  'Beginning in 2004, Marinero began to publicly support gay marriage as well[REF] .',
#  'Bush joined other children of prominent Republican politicians-including Meghan McCain and Mary Cheney-in endorsing gay marriage [REF].',
#  'Chafee opposes a constitutional amendment intended to ban gay marriage',
#  'Chafee opposes a constitutional amendment intended to ban gay marriage.',
#  'Cheney has publicly supported gay marriage since leaving the vice presidency [REF].',
#  "Cheney is openly gay, has voiced support for same-sex marriage, and has been credited with encouraging her father's approval of same-sex marriage,[REF] which he has publicly supported since leaving the vice presidency [REF].",
#  'Cheney spoke of his support for same-sex marriage, becoming one of the most prominent Republican politicians to do so',
#  'Cortez Masto supports gay marriage [REF].',
#  'Cupp, who identifies as a Log Cabin Republican, said the Republican Party should support gay marriage [REF].',
#  'David Blankenhorn called Gay Marriage "the most precise and serious argument to date in favor of the proposition that marriage supporters should accept gay marriage."',
#  'David Koch has voiced support for gay marriage and U.S. military withdrawal from the Middle East.',
#  'Davis, who long had a strong gay fan base, expressed support for gay men in her 1972 interview with The Advocate [REF].',
#  'During an ABC News interview in 2012, Barack Obama expressed his support for gay marriage, becoming the first US President to do so [REF].',
#  'EU nations legalising gay marriage is now an inevitability, and this was a routine amendment (no referendum involved',
#  'Empowered) is founded in New York City[REF]\nMassachusetts becomes the first state to legalize gay marriage.',
#  'Evidence of the secular nature of contemporary Spain can be seen in the widespread support for the legalization of same-sex marriage in Spain - over 70% of Spaniards support gay marriage according to a 2004 study by the Centre for Sociological Research [REF].',
#  'FWIW, Minnesota was actually the first state to reject a constitutional ban on gay marriage',
#  'FWIW, Minnesota was actually the first state to reject a constitutional ban on gay marriage.',
#  'FitzGerald released a plan for state-funded universal preschool in addition to announcing his support for gay marriage [REF].',
#  'Former presidents Bill Clinton[REF] and Jimmy Carter[REF] and former Vice Presidents Joe Biden, Al Gore[REF] and Walter Mondale[REF] also support gay marriage',
#  'Former presidents Bill Clinton[REF] and Jimmy Carter[REF] and former Vice Presidents Joe Biden, Al Gore[REF] and Walter Mondale[REF] also support gay marriage.',
#  "Gay activist Jonathan Rauch has argued that marriage is good for all men, whether homosexual or heterosexual, because engaging in its social roles reduces men's aggression and promiscuity [REF].",
#  'Gay marriage in the state of California is legalized after the stay held on the unconstitutional California Proposition 8 is lifted',
#  'Gay marriage is legal throughout Canada, so religious establishments that wish to can solemnise marriages',
#  'Gay marriage is now the norm in liberal democracies',
#  'Gay marriage was legally recognized in Canada in 2005.',
#  'Gay scene is good, and community is tolerant',
#  "Gillham actively supports the LGBTI community and expressed his strong support in favour for the 'Yes' campaign in Australia's Marriage Equality Postal Survey [REF].",
#  'Hanks supports same-sex marriage, environmental causes, and alternative fuels.',
#  'However, Cameron supported commitment for gay couples in a 2005 speech, and in October 2011 urged Conservative MPs to support gay marriage [REF].',
#  'Huntley came out in support of gay marriage',
#  'In 1978 the Provincetown Business Guild (PBG) was formed to promote gay tourism.',
#  'In 2006, he told Fox Sports: "I\'m a big advocate of gay marriage.',
#  'In 2012 a poll by MaltaToday[REF] showed that 41% of Maltese supported same-sex marriage, with support increasing to 60% amongst the 18-35 age group.',
#  'In 2012, President Barack Obama voiced support for gay marriage, and in the November elections, three states voted to legalize gay marriage at the ballot box for the first time in history[REF] while an attempt to restrict same-sex marriage was rejected.',
#  'In 2013, Hawaii voted in favor of gay marriage, and marriage licenses began to be issued to LGBT couples.',
#  "In 2014, he ruled that Pennsylvania's 1996 ban on same-sex marriage was unconstitutional.",
#  'In 2015, Giuliani came out in support of gay marriage, and signed an amicus brief calling for the Supreme Court to legalize gay marriage [REF].',
#  "In August 2018, the Costa Rican Supreme Court ruled in favor of lifting the same-sex marriage ban, giving the country's legislators 18 months to legalize same-sex marriage [REF].",
#  'In June 2011, nevertheless, Huntley came out in support of gay marriage, and voted for it in the successful 33-29 vote to pass it into law [REF].',
#  'In June 2015, the Supreme Court legalized gay marriage nationally in the case of Obergefell v. Hodges.',
#  'In June 2017, the Scottish Episcopal Church also approved of gay marriage within church canon law.',
#  'In May 2009, Cheney spoke of his support for same-sex marriage, becoming one of the most prominent Republican politicians to do so.',
#  "In October, 2014, a federal judge ruled that Arizona's law banning gay marriage was unconstitutional, and Horne did not appeal.",
#  "In Quinn's 2013 State of the State address, he declared his commitment to the legalization of gay marriage [REF].",
#  'In addition to being a vocal advocate of non-monogamy, Taormino supports gay marriage: "I support gay marriage being legalised in every state',
#  'In addition to being a vocal advocate of non-monogamy, Taormino supports gay marriage: "I support gay marriage being legalised in every state.',
#  'In recent years the more countries have come in support of same-sex marriage, with the number expected to increase.',
#  'In the House of Representatives, Andrew Wilkie and Cathy McGowan support same-sex marriage and prefer a parliamentary vote [REF].',
#  'In the United States[REF] and Spain,[REF] the majority of Catholics support gay marriage, followed by France at 43% support [REF].',
#  'Islam recognizes the value of sex and companionship and advocates marriage as the foundation for families and channeling the fulfillment of a base need.',
#  "January 12: U.S. District Judge Karen Schreier rules in Rosenbrahn v. Daugaard that South Dakota's ban on same-sex marriage is unconstitutional.",
#  "January 14: U.S. District Court Judge Terence C. Kern rules in Bishop v. Oklahoma that Oklahoma's ban on same-sex marriage is unconstitutional.",
#  'Keep - legalizing gay marriage in the region has become an important focal point of the same-sex marriage movement',
#  'LGBT activists subsequently urged the Knesset to act on the issue and legalise same-sex marriage',
#  "Law\nUS federal judge Joseph Louis Tauro, in two separate cases, rules that a federal ban against gay marriage is unconstitutional, as it interferes with a state's right to define marriage.",
#  'Macklemore & Ryan Lewis won four trophies, including Best New Artist, and led an industry show of support for gay marriage with a performance of their song "Same Love" to accompany a mass wedding of gay and heterosexual couples, which was presided over by Queen Latifah [REF].',
#  'Maine becomes the first state to legalize gay marriage via voter referendum',
#  'Maine becomes the first state to legalize gay marriage via voter referendum.',
#  'March 1 - Maryland becomes the 8th state to legalize gay marriage [REF].',
#  'March 2012 Miliband pledged his support for same sex marriage',
#  "Martin O'Malley, the Governor of the US state of Maryland, signs a law legalizing gay marriage in that state",
#  'Massachusetts Governor Charlie Baker "is socially liberal [..] He is pro-choice and has long supported gay marriage"',
#  'Massachusetts Governor Charlie Baker "is socially liberal [..] He is pro-choice and has long supported gay marriage".',
#  'May 9 - Barack Obama becomes the first sitting U.S. President to announce support for gay marriage [REF].',
#  'McCain also clarified that he does not support a federal ban on adoption by gay parents [REF].',
#  'Most Americans support gay marriage" in Wikipedia',
#  'Most California voters still oppose gay-marriage ban',
#  'Most Californian voters support gay marriage", it wouldn\'t bring attention to the ban',
#  'News interview in 2012, Barack Obama expressed his support for gay marriage',
#  'November - The church Seventy Jay Jensen told a reporter that the LDS church offers gay people help and support that will point them to happiness [REF].',
#  "Ohio's ban on gay marriage is unconstitutional",
#  'On June 24, 2011, Addabbo supported gay marriage by voting for the "Marriage Equality Enactment" Bill# A-8354, which successfully passed in the Senate [REF].',
#  'On March 25, 2013, Rockefeller announced his support for gay marriage [REF].',
#  'On May 6, 2009, Maine Governor John Baldacci signed a law legalizing same-sex marriage, becoming the first state governor to do so [REF].',
#  "On November 25, 2014, U.S. District Court Judge Carlton W. Reeves of the District Court for Southern Mississippi, ruled Mississippi's ban on same-sex marriage unconstitutional.",
#  "On October 17, 2014, a federal court found the state's ban on same-sex marriage unconstitutional.",
#  'On social issues he has supported gay marriage, answering an Associated Press reporter\'s question on the subject on Feb. 3, 2005, "I support gay marriage.',
#  'One year after repeal, a study published by the Palm Center found that openly gay service has not resulted in a negative net impact to the U.S. military [REF].',
#  'Pincher, who is openly gay, voted in favour of Marriage (Same Sex Couples) Act 2013, which legalised gay marriage [REF].',
#  'Politics and elections \nTens of thousands of people rally in Paris in support of the legalisation of gay marriage and adoption in France.',
#  'Polls conducted in the UK showed overall support for the marriage [REF].',
#  'Portman announced that he had changed his stance on gay marriage, and now is in support of its legalization',
#  'Public support for same-sex marriage is growing rapidly',
#  'Recent opinion polls have found that same-sex marriage enjoys very high levels of support [REF].',
#  'Recent polls have indicated that a majority of Californians support same-sex marriage.',
#  'Research by Coleman suggest that some develop a positive homosexual identity while maintaining a successful marriage [REF].',
#  'Rice is one of eight current openly-LGBTI members in the Parliament of Australia and supports Gay marriage in Australia.',
#  'Rishworth supports same-sex marriage having voted in support of a bill in Federal Parliament in 2012 and 2017 [REF].',
#  'Rodota later joined the Mehlman brief in support of gay marriage in Obergefell v. Hodges.[REF] .',
#  'Same-sex marriage has received support from many important figures and government organisations',
#  'Scaramucci has tweeted at various times that he has "always been for strong gun control laws", and that "Republicans should support gay marriage" [REF].',
#  'Select vendors in the DC area have come out enthusiastically in support of the gay marriage [REF].',
#  "She has long supported gay marriage and welcomed Spain's decision to recognize it [REF].",
#  'She supported the recent landmark case of Varnum v. Brien, which legalized gay marriage in the state.',
#  'She voted to support gay marriage and said she would "happily and without reservation" support it if the issue would come up again.',
#  'She, along with Meghan McCain and Margaret Hoover, released an ad in early 2013 in support of gay marriage.',
#  'Singer, whose son Andrew married his husband Corey Morris in a same-sex marriage in Massachusetts in 2009, has also financially supported the legalization of gay marriage in New York,[REF] and Maryland [REF].',
#  'Some people look at a poll that says "75% of Americans support gay marriage" and believe that they should put the fact "Most Americans support gay marriage" in Wikipedia.',
#  'Spearman, who is lesbian herself, supported gay marriage and abortion.',
#  'Springfield legalizes same-sex marriage to increase tourism',
#  'Subsequently, the APsaA became the first national mental health organization to support gay marriage, in 1997;[REF] a policy that was spearheaded by Isay.',
#  'That the CCAR oppose governmental efforts to ban gay and lesbian marriage.',
#  'The APA task force said ex-gay groups help counteract and buffer minority stress, marginalization, and isolation.',
#  'The Court also ordered the government to draft laws to legally recognize gay marriage.',
#  'The Episcopal Church in the U.S. has allowed gay marriage since 2015."[REF]',
#  'The French parliament recently voted to allow gay marriage - the OP is undoubtedly referring to that.',
#  'The Kingdom was dissolved on 17 November 2017 following the decision made by the Australian people to legalize gay marriage [REF].',
#  'The New York State alone has at least 89 State Assembly and 20 State Senate members who publicly proclaim their support for gay marriage',
#  'The New York State alone has at least 89 State Assembly and 20 State Senate members who publicly proclaim their support for gay marriage.',
#  'The RCP now strongly supports gay liberation.',
#  'The United Church of Christ and the Alliance of Baptists also condone gay marriage, and some parts of the Anglican and Lutheran churches allow for the blessing of gay unions.',
#  'The archbishop, who supported the prayers, "called for the church to take a clear and unequivocal stance in support of gay and lesbian couples" [REF].',
#  'The establishment of same-sex marriage is associated with a significant reduction in the rate of attempted suicide among children, with the effect being concentrated among children of a minority sexual orientation',
#  'The increased wealth of the gay community helped to promote a diversity of undergarment choices',
#  'The leaders said they would "rejoice" in the introduction of gay marriage [REF].',
#  'The logical coherence of the core Christian doctrines such as the Trinity, the Incarnation, the Resurrection and the Ascension is improved through the integration of gay marriage into the Christian conception of marriage [REF].',
#  'Their gay relationship is no longer criminal',
#  'This required the removal of the islanders and his solution was to ban marriage',
#  'Thompson did not support a federal ban on gay marriage',
#  'Trump was progressive on social issues, and supported allowing openly gay soldiers in the military, saying: "it would not disturb me" [REF].',
#  'Two months later, the Vietnamese Justice Minister, Ha Hung Cuong, announced that the Government was considering legalising same-sex marriage, stating that "in order to protect individual freedoms, same-sex marriage should be allowed."',
#  'Vermont joins New Hampshire, Massachusetts, Connecticut and Iowa to become the fifth American state to officially legalise gay marriage [REF].',
#  'Washington is the 7th state to legalize gay marriage',
#  'Washington is the 7th state to legalize gay marriage.',
#  'We should insist on gay marriage',
#  'Wiggins had supported the 2009 Varnum v. Brien which declared the ban on same-sex marriage unconstitutional',
#  'Wiggins had supported the 2009 Varnum v. Brien which declared the ban on same-sex marriage unconstitutional.',
#  'Zimmerman has indicated he will speak out on LGBTI issues and declared his support for Gay marriage in Australia[REF] and stated "I would have supported a free vote and preferred it to be decided by the Parliament.',
#  "a federal ban against gay marriage is unconstitutional, as it interferes with a state's right to define marriage",
#  'a. Tr 1025:4-23 (Lamb: Studies have demonstrated "very conclusively that children who are raised by gay and lesbian parents are just as likely to be well-adjusted as children raised by heterosexual parents."',
#  'anyone who opposes gay marriage is unreasonable',
#  'bans on same-sex marriage are unconstitutional, effectively legalizing same-sex marriage in the United States',
#  'by the 23rd century, same-sex marriage is perfectly legal not only on Earth but throughout Earth-controlled space',
#  'decision immediately legalizing same-sex marriage in Ontario, thereby becoming the first province where it was legal',
#  'ex-gay groups help counteract and buffer minority stress, marginalization, and isolation',
#  'gay marriage has been legal since 2006',
#  'gay marriage is made legal',
#  'gay marriages are now legal in a number of countries',
#  'gay men make better fighters, because, having no family, they are closer to their comrades',
#  'gay sex is not an inherently sinful practice',
#  'heterosexual marriage is one of several requirements for afterlife entry into the "highest degree of glory" in the celestial kingdom',
#  "lifting the ban on gay service did not have any negative effects on the ADF's morale, effectiveness or recruitment and retention, and may have led to increased productivity and improved working environments",
#  'of the RNC, Gillespie opposed same-sex marriage and supported the Republican platform plank in support of constitutional amendment banning gay marriage',
#  'openly gay service has not resulted in a negative net impact',
#  'public opinion polls currently indicate majority support for gay marriage among the people of the Commonwealth',
#  'same-sex marriage should be promoted as a way of increasing social stability, or integrating gay people into society',
#  'same-sex marriage would aid the city because "married individuals tend to accumulate more wealth than single individuals',
#  'the CCAR oppose governmental efforts to ban gay and lesbian marriage',
#  'the Supreme Court legalized gay marriage nationally in the case of Obergefell v. Hodges',
#  'the majority of Catholics support gay marriage',
#  'they supported an amendment to the constitution to legalize gay marriage']

# %%
import matplotlib.pyplot as plt

# %%
topic_and_narratives_df = pd.read_csv('../../data/top_20_big_issues_narratives.csv')

# %%
topic_and_narratives_df=topic_and_narratives_df.dropna()

# %%
len(topic_and_narratives_df)
# Out:
# 110

# %%
topic_and_narratives_df.head()
# Out:
#    Unnamed: 0         topic stance moral_class  \
# 0           0  Gay Marriage    pro     binding
# 1           1  Gay Marriage    con     binding
# 2           2  Gay Marriage    pro  individual
# 3           3  Gay Marriage    con  individual
# 4           4  Gay Marriage    pro     general
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       narrative
# 0                                                                                                      Greetings all. The crowd has contributed 886 arguments in support of the claim that Gay Marriage. Following is a summary of its thoughts. \n\nThere are four issues the crowd has raised, supporting the perception that Gay Marriage: majority, legalization, lgbt and men. \n\nRegarding majority.  The majority of Catholics support gay marriage.   In the United States and Spain, it support gay marriage, followed by France at 43% support.   Public opinion polls currently indicate majority support for gay marriage among the people of the Commonwealth.   Polls have shown that a majority of the Swiss population supports same-sex marriage, with the most recent one finding 75% support.  In 2012 a poll by MaltaToday showed that 41% of Maltese supported same-sex marriage, with support increasing to 60% amongst the 18-35 age group. \n\nNext, a few words about legalization.  Martin O'Malley, the Governor of the US state of Maryland, signs a law legalizing gay marriage in that state.   Keep - legalizing gay marriage in the region has become an important focal point of the same-sex marriage movement.  Singer, whose son Andrew married his husband Corey Morris in a same-sex marriage in Massachusetts in 2009, has also financially supported the legalization of gay marriage in New York, and Maryland.  In Quinn's 2013 State of the State address, he declared his commitment to the legalization of gay marriage.  \n\nThe next issue is lgbt.  Spearman, who is lesbian herself, supported gay marriage and abortion.   The establishment of same-sex marriage is associated with a significant reduction in the rate of attempted suicide among children, with the effect being concentrated among children of a minority sexual orientation.   60% of Catholics favor allowing gay and lesbian couples to marry legally, compared to 55% of Americans as a whole.  \n\nThe last issue is men.  A study of the conditions for gay men indicates that gay men in the Danish Defence show strength and are respected.   Gay activist Jonathan Rauch has argued that marriage is good for all men, whether homosexual or heterosexual, because engaging in its social roles reduces men's aggression and promiscuity.   Gay men make better fighters, because, having no family, they are closer to their comrades.  \n\nFor all these reasons, the crowd is supporting the notion that Gay Marriage. Thanks for tuning in.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                               Hello everybody. The crowd posted 886 arguments, opposing the claim that Gay Marriage. Here is a summary. \n\nThere are four issues the crowd has raised, opposing the perception that Gay Marriage: bans, bestiality, wrongs and proposition 8. \n\nRegarding bans.  The 2012 Minnesota constitutional amendment to ban gay marriage.  In 2005, she led a march to her father's gravesite and at the same time called out for a constitutional ban on gay marriage.  Hunter opposed same-sex marriage, and proposed a constitutional amendment to ban same-sex marriage.  According to a poll, conducted in February 2005 by Research 2000 for the Concord Monitor, 51% of likely voters in the state supported a federal constitutional amendment to ban same-sex marriage. \n\nNext, a few words about bestiality.  Gay marriage will lead to legalized bestiality.   It is a threat to all marriage.   Allowing gay marriage would lead to legal bestiality.   Conservatives use the argument that legalizing gay marriage will ultimately lead to legalized bestiality.   Gay behavior should be a criminal offense.  \n\nThe next issue is wrongs.  Gay marriage is wrong.   Marriage is the wrong goal, as it is an institution rooted in sexism.   Homosexual marriage is wrong, then that would seem to be pretty strong evidence that it is wrong.   Sex outside of marriage is sinful, and therefore gay sex is sinful.  \n\nThe last issue is proposition 8.  Proposition 8, which banned gay marriage within California.   Korean-Americans, due to their Republican and Christian leanings, overwhelmingly supported California's constitutional gay marriage ban, Proposition 8.  In 2008, Blake's President Brian Rule donated $10,000 to support California Proposition 8, which temporarily banned gay marriage in California.  In October 2008, he appeared alongside Rev. Jim Franklin of Cornerstone Church, to oppose gay marriage and support Proposition 8, the California same-sex marriage ban.  \n\nFor all these reasons, the crowd is opposing the notion that Gay Marriage. Thanks for tuning in.
# 2                                                                 Greetings all. The crowd has contributed 420 arguments in support of the claim that Gay Marriage. Following is a summary of its thoughts. \n\nThere are four issues that will be addressed. The first will explain that Gay marriage doesn't damage children. Then, the topics of lgbt rights, lgbt and bans will be elaborated on. \n\nRegarding children.  Adopting same-sex marriage would be likely to improve the well-being of gay and lesbian households and their children.   By fostering better life decisions and stronger relationship skills, marriage programs can increase child well-being and adult happiness and reduce child poverty and welfare dependence.  \n\nNext, a few words about lgbt rights.  Some representatives in the Diocese of Uruguay have supported gay and lesbian rights.   Lesbian, gay and bisexual people should be regarded as valued members of society who have exactly similar rights and responsibilities as all other citizens.  In 2011, Clinton took a similar position on LGBT rights in a speech to the United Nations on International Human Rights Day, declaring "gay rights are human rights, and human rights are gay rights.". \n\nThe next issue is lgbt. According to the International Lesbian, Gay, Bisexual, Trans and Intersex Association, Sweden is one of Europe's most gay-friendly countries, with extensive legislation protecting gay and lesbian rights, including anti-discrimination law and same-sex marriage legislation.  The CCAR supported the right of gay and lesbian couples to share fully and equally in the rights of civil marriage and opposed governmental efforts to ban gay and lesbian marriage.   It oppose governmental efforts to ban gay and lesbian marriage.   A October 2012 Washington Post poll found wide support for gay marriage among Florida voters, reflecting the changing attitudes toward LGBT residents of the state.  \n\nThe last issue is bans.  Bans on gay marriage violate Equal Protection and substantive due process rights.   The court finds the prohibition of gay marriage unconstitutional because it denies dignity and equality of all individuals.  When the Supreme Court took up the issue in 2015, Sanders issued a statement reaffirming his support, saying gay Americans in every state should be allowed to marry: "Of course all citizens deserve equal rights. \n\nFor all these reasons, the crowd is supporting the notion that Gay Marriage. Thanks for tuning in.
# 3                                                                                                                                                                                                                    Hello everybody. The crowd posted 420 arguments, opposing the claim that Gay Marriage. Here is a summary. \n\nThere are four issues the crowd has raised, opposing the perception that Gay Marriage: damage, societies, children and gay. \n\nRegarding damage.  Plural marriage would inflict terrible damage, that he ran the risk of wrecking his marriage and alienating his followers.   A gay bill because it is damaging to the survival of the country.   Gay marriage was evil.   It is wrong.   Gay marriage and incest are bad for society.  \n\nNext, a few words about societies.  Same-sex marriage would harm society or the institution of marriage.   It is a form of "extreme human rights" and "will create social problems.   A functioning marriage culture serves to protect political liberty and foster limited government.   Marriage is the most important social institution in our society.  It is considered the source of inner knowledge of life according to the Ayyavazhi ideas. \n\nThe next issue is children.  Gay people are more likely to be abused as children.  In 2005, he resurrected his legislation that would ban gay people from adopting children, claiming that gay people were more prone to violence, alcoholism, and suicide.  The gay parade doesn't have any benefits because it provokes hatred among intolerant people is absurd.   The plaintiffs proved how Berk posted answers to questions about homosexuality that said gay people were "sick," "disordered," and "broken" and that gay people were likely to become alcoholics, abuse children, and die of AIDS.  \n\nThe last issue is gay.  GLAAD describes the association of homosexuality with pedophilia or child abuse as an attempt to "insinuate that lesbians and gay men pose a threat to society, to families, and to children in particular.".   Russia's gay propaganda law encourages homophobia, reinforces prejudice and violates the right to freedom of speech.   Gay and lesbian youth can develop severe forms of depression and anxiety as they grow up.   The United Nations views forced marriage as a form of human rights abuse, since it violates the principle of the freedom and autonomy of individuals.  \n\nFor all these reasons, the crowd is opposing the notion that Gay Marriage. Thanks for tuning in.
# 4  Greetings all. The crowd has contributed 1355 arguments in support of the claim that Gay Marriage. Following is a summary of its thoughts. \n\nThere are four issues the crowd has raised, supporting the perception that Gay Marriage: vote, unconstitutional, lgbt rights and Barack Obama. \n\nRegarding vote.  An August 2012 Public Policy Polling survey found that a plurality of voters in the state supported same-sex marriage.   A October 2012 Washington Post poll found wide support for gay marriage among Florida voters, reflecting the changing attitudes toward LGBT residents of the state.  In 2012 a poll by MaltaToday showed that 41% of Maltese supported same-sex marriage, with support increasing to 60% amongst the 18-35 age group. \n\nNext, a few words about unconstitutional.  Bans on same-sex marriage are unconstitutional, effectively legalizing same-sex marriage in the United States.   A federal ban against gay marriage is unconstitutional, as it interferes with a state's right to define marriage.  In 2014, he ruled that Pennsylvania's 1996 ban on same-sex marriage was unconstitutional. \n\nThe next issue is lgbt rights.  In a speech before the United Nations Human Rights Council in December 2011, Clinton said that "Gay rights are human rights" and that the U.S. would advocate for gay rights and legal protections of gays abroad.   In an interview on The Howard Stern Show, he reaffirmed his support of gay rights, including in marriage and military service, humorously stating he would have gladly served alongside homosexuals when he was in the Navy as they would have provided less competition for women.   Polls show that public belief that AIDS is the nation's "most urgent health problem" has declined from 38% to 7% since Sexual Ecology was published, and support for gay rights is at an all time high.  \n\nThe last issue is Barack Obama. During an ABC News interview in 2012, Barack Obama expressed his support for gay marriage, becoming the first US President to do so.  Polis has also credited President Obama for openly endorsing gay marriage calling it "welcome news to American families.".  In 2012, President Barack Obama voiced support for gay marriage, and in the November elections, three states voted to legalize gay marriage at the ballot box for the first time in history while an attempt to restrict same-sex marriage was rejected. \n\nFor all these reasons, the crowd is supporting the notion that Gay Marriage. Thanks for tuning in.

# %%
topic_and_narratives_df['narrative_paras'] = topic_and_narratives_df.narrative.apply(lambda x: x.split('\n\n')[2:-1])
topic_and_narratives_df['narrative_paras'] = topic_and_narratives_df.narrative_paras.apply(lambda paras:
                                                list(zip(paras, bert_moral_classification.get_arg_morals(paras))))

# %%
topic_and_narratives_df['narrative_morals'] = topic_and_narratives_df.narrative_paras.apply(lambda paras: [x[1] for x in paras])

# %%
topic_and_narratives_df[['topic', 'stance', 'moral_class', 'narrative_morals']].head(n=100)
# Out:
#                       topic stance moral_class  \
# 0              Gay Marriage    pro     binding
# 1              Gay Marriage    con     binding
# 2              Gay Marriage    pro  individual
# 3              Gay Marriage    con  individual
# 4              Gay Marriage    pro     general
# ..                      ...    ...         ...
# 97   Legalized Prostitution    con  individual
# 98   Legalized Prostitution    pro     general
# 99   Legalized Prostitution    con     general
# 100               Socialism    pro     binding
# 101               Socialism    con     binding
#
#                                                                                            narrative_morals
# 0                                          [{care, authority}, {authority}, {care, authority}, {authority}]
# 1                                    [{fairness, authority}, {authority}, {purity, authority}, {authority}]
# 2         [{authority, care, loyalty}, {fairness, authority}, {fairness, authority}, {fairness, authority}]
# 3    [{authority, loyalty}, {fairness, purity, authority}, {purity, authority, care}, {authority, loyalty}]
# 4                                      [{care, authority}, {authority}, {fairness, authority}, {authority}]
# ..                                                                                                      ...
# 97                             [{authority}, {fairness, authority}, {purity, authority}, {care, authority}]
# 98                                               [{authority}, {care, authority}, {authority}, {authority}]
# 99                         [{fairness, authority}, {purity, authority}, {fairness, authority}, {authority}]
# 100                                   [{authority}, {authority}, {authority, loyalty}, {purity, authority}]
# 101                                  [{fairness, authority}, {authority}, {purity, authority}, {authority}]
#
# [100 rows x 4 columns]

# %%
binding_args = [moral for narrative in topic_and_narratives_df[topic_and_narratives_df.moral_class=='binding'].narrative_morals.tolist() for para in narrative for moral in para]
ind_args = [moral for narrative in topic_and_narratives_df[topic_and_narratives_df.moral_class=='individual'].narrative_morals.tolist() for para in narrative for moral in para]
general_args = [moral for narrative in topic_and_narratives_df[topic_and_narratives_df.moral_class=='general'].narrative_morals.tolist() for para in narrative for moral in para]

plt.hist([ind_args, binding_args, general_args], label=['ind', 'bind', 'general'])
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# %autoreload
import utils
import json
from moral_debater import *
import pandas as pd
import bert_moral_classification

pd.set_option('display.max_colwidth', None)

# %%
topic_narratives = collect_narratives_via_classifier(['Gay Marriage'], moral_dict, 100, [], use_cache=False)
# Out:
# TermWikifierClient:   0%|          | 0/1 [00:00<?, ?it/s]
# TermWikifierClient: 100%|██████████| 1/1 [00:00<00:00,  3.10it/s]
# [['Same-sex marriage']]
# EvidenceDetectionClient:   0%|          | 0/237 [00:00<?, ?it/s]
# Topic:Gay Marriage, Moral:binding
# ['The state recorded the highest Yes votes of any state in the republic referendum and same-sex marriage survey.', 'Group marriage is a form of non-monogamy and polyamory.', 'Their marriage appears to have been a happy one.', 'That led to marriage and the birth of his daughter, Emily.', 'The strain on his marriage led to his divorce.', 'Milano Pride is one of the largest gay and lesbian organized events in Italy.', 'Homok is associated with marriage because the Thai people believe that the marriage of ingredients within the homok is representative of the love of a married couple.', 'During the marriage campaign, support for gay marriage increased by 14 points, volunteers collected 160,000 signatures to put gay marriage on the ballot, and the marriage campaign raised $3 million [REF].', 'His second marriage resulted in no offspring.', "The Court concluded that the marriage violated Oregon's miscegenation law.", 'I accept that the subject clearly does not support same sex marriage and such like - but I request again - please provide independent reliable secondary reports that discuss this about the subject so as I can assess the situation and any desired addition.', 'Charles Larkey and Carole King began an intimate affair that would eventually lead to marriage [REF].', 'The problem with calling it "pro-marriage" is that it\'s only pro-marriage in general if gay marriage is a threat to all marriage, which few (if any) people in favor of gay marriage believe.', 'In the survey, 54% said that same sex marriage should be legal, while 33% were opposed.', 'The Marriage Act 1854, an early law in the colony governing marriage \nThe Marriage Act 1955, the current Act \nThe Marriage (Definition of Marriage) Amendment Act 2013 .', 'Conversely, marriage reduces male criminality [REF].', 'Same-sex marriage\nSame-sex marriage in Belgium\nSame-sex marriage in Canada\nSame-sex marriage in the Netherlands\nSame-sex marriage in South Africa\nSame-sex marriage in Spain\nSame-sex marriage in Massachusetts\nSame-sex marriage in Israel\nCivil union .', 'Members did not limit activism to gay causes.', 'The marriage performer issues a marriage certificate.', 'Prime Minister Malcolm Turnbull pledged the government would facilitate the passage of a private member\'s bill in the event of a "Yes" result in favour of same-sex marriage, which occurred when the results of the survey were announced by the Australian Bureau of Statistics on 15 November 2017 [REF].', 'A number of politicians, public figures, media outlets, businesses and other organisations endorsed voting either in favour or against same-sex marriage during the Australian Marriage Law Postal Survey.', 'He began a romance with María Laura Groba which did not lead to marriage.', 'Engagement -\nMarriage -\nMarriage partners -\nHusband -\nWife -\nTypes of marriage -\nArranged marriage -\nForced marriage -\nCousin marriage -\nOpen marriage -\nCivil union -\nDomestic partnership -\nBoyfriend -\nGirlfriend-\nFamilial relationship - relationship between members of a family.', 'The marriage does not appear to have been a happy one.', 'This second marriage resulted in an illegitimate daughter [REF].', 'A consensual group marriage is a form of polyarmory.', 'One gift is a ring, which leads to an impassioned marriage proposal, which she rejects.', 'Marriage and its customs and practices in a particular culture \nChristian views on marriage\nIslamic views on marriage\nOpposite-sex marriage, used primarily by opponents of same-sex marriage.', 'However, he voted in favour of the Marriage Amendment (Definition and Religious Freedoms) Act 2017, which legalised same-sex marriage; 65 percent of his constituency voted "Yes" in the Australian Marriage Law Postal Survey [REF].', 'Child marriage remains common in Northern Nigeria [REF].', 'Gay is good, gay is proud."', 'Each of the political parties represented in the Australian Parliament held formalised positions on same-sex marriage and on the merits of the survey. ...
# EvidenceDetectionClient: 100%|██████████| 237/237 [00:00<00:00, 556.09it/s]
#
# ClaimDetectionClient:   0%|          | 0/237 [00:00<?, ?it/s]
# Number of evidences: 16
# ClaimDetectionClient: 100%|██████████| 237/237 [00:00<00:00, 561.88it/s]
#
# ClaimBoundariesClient:   0%|          | 0/29 [00:00<?, ?it/s]
# Number of claims: 29
# ClaimBoundariesClient: 100%|██████████| 29/29 [00:00<00:00, 90.27it/s]
#
# ProConClient:   0%|          | 0/41 [00:00<?, ?it/s]
# ProConClient: 100%|██████████| 41/41 [00:01<00:00, 36.28it/s]
# Same-sex marriage
# Gay Marriage
# 22/07/2021 14:08:56, SpeechResultResponse=60f97bf789eaee050fc808f1, motionGenerationid=0, status=RUNNING, started to wait at 22/07/2021 14:08:56
# ProConClient:   0%|          | 0/41 [00:00<?, ?it/s]
# Narrative is empty...
# ProConClient: 100%|██████████| 41/41 [00:00<00:00, 124.48it/s]
# Same-sex marriage
# Gay Marriage
# 22/07/2021 14:09:08, SpeechResultResponse=60f97c0389eaee050fc808f4, motionGenerationid=0, status=RUNNING, started to wait at 22/07/2021 14:09:07
# EvidenceDetectionClient:   0%|          | 0/140 [00:00<?, ?it/s]
# Topic:Gay Marriage, Moral:individual
# ["Just like Ex-gay movement or Ex-gay is related to Gay and Gay rights movement, but that doesn't mean that we should merge Ex-gay movement to Gay rights movement or sometning.--В", 'Conservative pro-gay-marriage columnist S.E.', 'The marriage leads to tension between Marge and Selma.', 'People who oppose what gay rights supporters would call gay rights oppose them as rights at all, so they are definitionally opposed to gay rights.', 'On gay rights issues, the party supports possibilities for gay couples to live together, but opposes gay marriage and gay adoption rights.', 'Meyers supports gay rights [REF].', 'Anti gay-marriage, pro gay rights otherwise.', 'The State shall also protect and encourage marriage.', 'While I am against gay discrimination, I am also against gay parenthood and gay marriage (I would vote this way).', 'Marriage Equality or Gay Marriage;\nHabeas Corpus;\nAffirmative Action; and \nTitle IX.', 'My intent was to send a message and support gay rights.', 'Gay marriage and alternative defintitions of marriage are only recent.', 'Some have credited her contribution to the Same Sex Marriage Survey as having been "crucial" [REF] to the outcome.', 'A Sexton Research survey, commissioned by Marriage Alliance (a group which does not support same-sex marriage) was undertaken in July 2015.', "Saarikoski has criticized the citizens' initiative, and argued that gay marriage is a bad political goal.", 'Throughout its history, the club has been associated with the gay rights movement.', "Don't redirect as marriage covers gay marriage too.", 'A situation arises that leads to their marriage.', 'In any case, such a marriage would have been bigamous.', 'This marriage led to considerable political advantages for Dionysius.', 'Drag is closely associated with gay men and gay culture.', 'It does seem like there is literature on speech mannerisms which are associated with gay stereotypes.', 'American courts (like British courts) should be able to offer "forced marriage protection orders" to protect girls and women who face a looming forced marriage.', 'Would that justify including critics of gay marriage who were interviewed by the Daily Show in the gay marriage section?', 'The Campaign for Homosexual Equality (CHE) is one of the oldest gay rights organisations in the United Kingdom.', 'Can we conclude Jedis are more likely to be gay?', 'In the book Foote discusses various issues that he believed could have a detrimental effect on marriage.', 'Australian comedian and musician Tim Minchin uploaded a parody of the song called "I Still Call Australia Homophobic" to his Facebook page[REF] in reference to the same-sex marriage debate and proposed 2017 survey in Australia.', 'Gay San Francisco, Gay Amsterdam, Gay Paris?', "When Sipowicz's relationship with Sylvia leads to marriage, he asks Simone to be his best man.", '"gay porn turned them gay"?', 'I am going to sing lesbian love songs and support gay rights no matter what.', 'The term is primarily associated with gay and lesbian relationships.', 'He has publicly stated that he will vote against marriage equality in the parliament regardless of the results of the Australian Marriage Law Postal Survey [REF].', 'Gay UK → Draft:The Gay UK: As above.', "Ethel is unhappy with her marriage because of Frank's homosexuality.", 'Many platform planks expressing "disapproval of homosexuality, same-sex marriage or transgender rights"-championed by Tony Perkins, the president of the Family Research Council-passed [REF].', 'Their marriage resulted in the birth of ten children: .', "Meaning=We don't have to suppose that love is necessary for marriage.", 'It is one of the most influential gay films from the Philippines [REF].', 'Young believes marriage should be between a man and a woman.', 'A small organization that does fundraisers to promote gay rights organizations \nA militant gay rights collective in Montreal, Quebec \nA militant gay rights organization active in Colorado and Wyoming .', 'Falco ...
# EvidenceDetectionClient: 100%|██████████| 140/140 [00:18<00:00,  7.67it/s]
#
# ClaimDetectionClient:   0%|          | 0/140 [00:00<?, ?it/s]
# Number of evidences: 6
# ClaimDetectionClient: 100%|██████████| 140/140 [00:18<00:00,  7.65it/s]
#
# ClaimBoundariesClient:   0%|          | 0/9 [00:00<?, ?it/s]
# Number of claims: 9
# ClaimBoundariesClient: 100%|██████████| 9/9 [00:01<00:00,  8.89it/s]
#
# ProConClient:   0%|          | 0/15 [00:00<?, ?it/s]
# ProConClient: 100%|██████████| 15/15 [00:00<00:00, 19.10it/s]
# Same-sex marriage
# Gay Marriage
# 22/07/2021 14:09:58, SpeechResultResponse=60f97c3589eaee050fc808f7, motionGenerationid=0, status=RUNNING, started to wait at 22/07/2021 14:09:57
# ProConClient:   0%|          | 0/15 [00:00<?, ?it/s]
# Narrative is empty...
# ProConClient: 100%|██████████| 15/15 [00:00<00:00, 46.40it/s]
# Same-sex marriage
# Gay Marriage
# 22/07/2021 14:10:09, SpeechResultResponse=60f97c41ed7ca41fdb889823, motionGenerationid=0, status=RUNNING, started to wait at 22/07/2021 14:10:09
# EvidenceDetectionClient:   0%|          | 0/391 [00:00<?, ?it/s]
# Narrative is empty...
# EvidenceDetectionClient: 100%|██████████| 391/391 [00:28<00:00, 13.53it/s]
#
# ClaimDetectionClient:   0%|          | 0/391 [00:00<?, ?it/s]
# Number of evidences: 23
# ClaimDetectionClient: 100%|██████████| 391/391 [00:20<00:00, 19.52it/s]
#
# ClaimBoundariesClient:   0%|          | 0/40 [00:00<?, ?it/s]
# Number of claims: 40
# ClaimBoundariesClient: 100%|██████████| 40/40 [00:00<00:00, 124.29it/s]
#
# ProConClient:   0%|          | 0/59 [00:00<?, ?it/s]
# ProConClient: 100%|██████████| 59/59 [00:00<00:00, 127.41it/s]
# Same-sex marriage
# Gay Marriage
# 22/07/2021 14:11:10, SpeechResultResponse=60f97c7eed7ca41fdb889826, motionGenerationid=0, status=RUNNING, started to wait at 22/07/2021 14:11:10
# ProConClient:   0%|          | 0/59 [00:00<?, ?it/s]
# Topic:Gay Marriage, Moral:general
# General Narrative is empty...
# ProConClient: 100%|██████████| 59/59 [00:00<00:00, 183.16it/s]
# Same-sex marriage
# Gay Marriage
# 22/07/2021 14:11:22, SpeechResultResponse=60f97c8a89eaee050fc808fa, motionGenerationid=0, status=RUNNING, started to wait at 22/07/2021 14:11:22
# Topic:Gay Marriage, Moral:general
